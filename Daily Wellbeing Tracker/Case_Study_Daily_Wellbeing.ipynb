# %%
import pandas as pd
import numpy as np

# %%
#import data
daily_activity_df = pd.read_csv('/content/dailyActivity_merged.csv')
hourly_calories_df = pd.read_csv('/content/hourlyCalories_merged.csv')
hourly_intensities_df = pd.read_csv('/content/hourlyIntensities_merged.csv')
hourly_steps_df = pd.read_csv('/content/hourlySteps_merged.csv')
sleep_day_df = pd.read_csv('/content/sleepDay_merged.csv')
weight_log_df = pd.read_csv('/content/weightLogInfo_merged.csv')

# %%
#Look at first 5 raws of each table
daily_activity_df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 6.06                      0.0                 25
# 1                 4.71                      0.0                 21
# 2                 3.91                      0.0                 30
# 3                 2.83                      0.0                 29
# 4                 5.04                      0.0                 36
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   13                   328               728      1985
# 1                   19                   217               776      1797
# 2                   11                   181              1218      1776
# 3                   34                   209               726      1745
# 4                   10                   221               773      1863

# %%
hourly_calories_df.head()
# Out:
#            Id           ActivityHour  Calories
# 0  1503960366  4/12/2016 12:00:00 AM        81
# 1  1503960366   4/12/2016 1:00:00 AM        61
# 2  1503960366   4/12/2016 2:00:00 AM        59
# 3  1503960366   4/12/2016 3:00:00 AM        47
# 4  1503960366   4/12/2016 4:00:00 AM        48

# %%
hourly_intensities_df.head()
# Out:
#            Id           ActivityHour  TotalIntensity  AverageIntensity
# 0  1503960366  4/12/2016 12:00:00 AM              20          0.333333
# 1  1503960366   4/12/2016 1:00:00 AM               8          0.133333
# 2  1503960366   4/12/2016 2:00:00 AM               7          0.116667
# 3  1503960366   4/12/2016 3:00:00 AM               0          0.000000
# 4  1503960366   4/12/2016 4:00:00 AM               0          0.000000

# %%
hourly_steps_df.head()
# Out:
#            Id           ActivityHour  StepTotal
# 0  1503960366  4/12/2016 12:00:00 AM        373
# 1  1503960366   4/12/2016 1:00:00 AM        160
# 2  1503960366   4/12/2016 2:00:00 AM        151
# 3  1503960366   4/12/2016 3:00:00 AM          0
# 4  1503960366   4/12/2016 4:00:00 AM          0

# %%
weight_log_df.head()
# Out:
#            Id                   Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1  1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2  1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3  2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
#
#          BMI  IsManualReport          LogId
# 0  22.650000            True  1462233599000
# 1  22.650000            True  1462319999000
# 2  47.540001           False  1460509732000
# 3  21.450001            True  1461283199000
# 4  21.690001            True  1463097599000

# %%
sleep_day_df.head()
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
# Let's see viraety it time in sleep_day_df date
sleep_day_df['SleepDay'].unique()
# Out:
# array(['4/12/2016 12:00:00 AM', '4/13/2016 12:00:00 AM',
#        '4/15/2016 12:00:00 AM', '4/16/2016 12:00:00 AM',
#        '4/17/2016 12:00:00 AM', '4/19/2016 12:00:00 AM',
#        '4/20/2016 12:00:00 AM', '4/21/2016 12:00:00 AM',
#        '4/23/2016 12:00:00 AM', '4/24/2016 12:00:00 AM',
#        '4/25/2016 12:00:00 AM', '4/26/2016 12:00:00 AM',
#        '4/28/2016 12:00:00 AM', '4/29/2016 12:00:00 AM',
#        '4/30/2016 12:00:00 AM', '5/1/2016 12:00:00 AM',
#        '5/2/2016 12:00:00 AM', '5/3/2016 12:00:00 AM',
#        '5/5/2016 12:00:00 AM', '5/6/2016 12:00:00 AM',
#        '5/7/2016 12:00:00 AM', '5/8/2016 12:00:00 AM',
#        '5/9/2016 12:00:00 AM', '5/10/2016 12:00:00 AM',
#        '5/11/2016 12:00:00 AM', '4/14/2016 12:00:00 AM',
#        '4/22/2016 12:00:00 AM', '4/27/2016 12:00:00 AM',
#        '5/4/2016 12:00:00 AM', '5/12/2016 12:00:00 AM',
#        '4/18/2016 12:00:00 AM'], dtype=object)

# %%
#As we see there each date has time 12 AM so we can remove it
sleep_day_df['SleepDay'] = pd.to_datetime(sleep_day_df['SleepDay']).dt.date
sleep_day_df.head()
# Out:
#            Id    SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  2016-04-12                  1                 327
# 1  1503960366  2016-04-13                  2                 384
# 2  1503960366  2016-04-15                  1                 412
# 3  1503960366  2016-04-16                  2                 340
# 4  1503960366  2016-04-17                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
print(len(daily_activity_df))
print(len(sleep_day_df))
# Out:
# 940
# 413

# %%
#Let's merge sleep data to daily data
daily_activity_df['ActivityDate'] = pd.to_datetime(daily_activity_df['ActivityDate']).dt.date
daily_activity_df = pd.merge(daily_activity_df, sleep_day_df, left_on=['Id', 'ActivityDate'], right_on=['Id', 'SleepDay'], how='left')
daily_activity_df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-04-12       13162           8.50             8.50
# 1  1503960366   2016-04-13       10735           6.97             6.97
# 2  1503960366   2016-04-14       10460           6.74             6.74
# 3  1503960366   2016-04-15        9762           6.28             6.28
# 4  1503960366   2016-04-16       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 6.06                      0.0                 25
# 1                 4.71                      0.0                 21
# 2                 3.91                      0.0                 30
# 3                 2.83                      0.0                 29
# 4                 5.04                      0.0                 36
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   13                   328               728      1985
# 1                   19                   217               776      1797
# 2                   11                   181              1218      1776
# 3                   34                   209               726      1745
# 4                   10                   221               773      1863
#
#      SleepDay  TotalSleepRecords  TotalMinutesAsleep  TotalTimeInBed
# 0  2016-04-12                1.0               327.0           346.0
# 1  2016-04-13                2.0               384.0           407.0
# 2         NaN                NaN                 NaN             NaN
# 3  2016-04-15                1.0               412.0           442.0
# 4  2016-04-16                2.0               340.0           367.0

# %%
#Mergin hourly DataFrames by Id and ActivityHour

hourly_activity_df = pd.merge(hourly_steps_df, hourly_calories_df, on=['Id', 'ActivityHour'], how='inner')
hourly_activity_df = pd.merge(hourly_activity_df, hourly_intensities_df, on=['Id', 'ActivityHour'], how='inner')
hourly_activity_df.head()
# Out:
#            Id           ActivityHour  StepTotal  Calories  TotalIntensity  \
# 0  1503960366  4/12/2016 12:00:00 AM        373        81              20
# 1  1503960366   4/12/2016 1:00:00 AM        160        61               8
# 2  1503960366   4/12/2016 2:00:00 AM        151        59               7
# 3  1503960366   4/12/2016 3:00:00 AM          0        47               0
# 4  1503960366   4/12/2016 4:00:00 AM          0        48               0
#
#    AverageIntensity
# 0          0.333333
# 1          0.133333
# 2          0.116667
# 3          0.000000
# 4          0.000000

# %%
#Check information about tables

#We can see that no columns exept column fat in weight log have any nan
print(hourly_activity_df.info())
print(daily_activity_df.info())
print(weight_log_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22099 entries, 0 to 22098
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                22099 non-null  int64
#  1   ActivityHour      22099 non-null  object
#  2   StepTotal         22099 non-null  int64
#  3   Calories          22099 non-null  int64
#  4   TotalIntensity    22099 non-null  int64
#  5   AverageIntensity  22099 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 1.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 943 entries, 0 to 942
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        943 non-null    int64
#  1   ActivityDate              943 non-null    object
#  2   TotalSteps                943 non-null    int64
#  3   TotalDistance             943 non-null    float64
#  4   TrackerDistance           943 non-null    float64
#  5   LoggedActivitiesDistance  943 non-null    float64
#  6   VeryActiveDistance        943 non-null    float64
#  7   ModeratelyActiveDistance  943 non-null    float64
#  8   LightActiveDistance       943 non-null    float64
#  9   SedentaryActiveDistance   943 non-null    float64
#  10  VeryActiveMinutes         943 non-null    int64
#  11  FairlyActiveMinutes       943 non-null    int64
#  12  LightlyActiveMinutes      943 non-null    int64
#  13  SedentaryMinutes          943 non-null    int64
#  14  Calories                  943 non-null    int64
#  15  SleepDay                  413 non-null    object
#  16  TotalSleepRecords         413 non-null    float64
#  17  TotalMinutesAsleep        413 non-null    float64
#  18  TotalTimeInBed            413 non-null    float64
# dtypes: float64(10), int64(7), object(2)
# memory usage: 147.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              67 non-null     int64
#  1   Date            67 non-null     object
#  2   WeightKg        67 non-null     float64
#  3   WeightPounds    67 non-null     float64
#  4   Fat             2 non-null      float64
#  5   BMI             67 non-null     float64
#  6   IsManualReport  67 non-null     bool
#  7   LogId           67 non-null     int64
# dtypes: bool(1), float64(4), int64(2), object(1)
# memory usage: 3.9+ KB
# None

# %%
#Let's drop duplicats if we have any

hourly_activity_df =hourly_activity_df.drop_duplicates()
daily_activity_df =daily_activity_df.drop_duplicates()
weight_log_df =weight_log_df.drop_duplicates()

# %%
#Let's check how many unique users are in data
print('Hourly activity: ', len(hourly_activity_df['Id'].unique()))
print('Daily activity: ', len(daily_activity_df['Id'].unique()))
print('Weight log: ', len(weight_log_df['Id'].unique()))
# Out:
# Hourly activity:  33
# Daily activity:  33
# Weight log:  8

# %%
#Export data to csv
hourly_activity_df.to_csv('hourly_activity_df.csv', index=False)
daily_activity_df.to_csv('daily_activity_df.csv', index=False)
